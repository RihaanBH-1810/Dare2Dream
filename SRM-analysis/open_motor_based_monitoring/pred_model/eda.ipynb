# %%
import pandas as pd

# %%
file = pd.read_csv("merged_dataset.csv")

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3012473 entries, 0 to 3012472
# Data columns (total 17 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   Time(s)                       float64
#  1   Kn                            float64
#  2   Chamber Pressure(Pa)          float64
#  3   Thrust(N)                     float64
#  4   Propellant Mass(G1;kg)        float64
#  5   Volume Loading(%)             float64
#  6   Mass Flow(G1;kg/s)            float64
#  7   Mass Flux(G1;kg/(m^2*s))      float64
#  8   Regression Depth(G1;m)        float64
#  9   Web(G1;m)                     float64
#  10  Nozzle Exit Pressure(Pa)      float64
#  11  Change in Throat Diameter(m)  float64
#  12  type                          object
#  13  Time                          float64
#  14  CP                            float64
#  15  Th                            float64
#  16  CD                            float64
# ...

# %% [markdown]
# ##
